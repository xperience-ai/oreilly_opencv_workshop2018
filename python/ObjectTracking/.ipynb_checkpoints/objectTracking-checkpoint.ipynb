# %% [markdown]
# # Object Tracking
# **Satya Mallick, LearnOpenCV.com**

# %%
# Import modules
import cv2
import sys
import os
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

def drawRectangle(frame, bbox):
    p1 = (int(bbox[0]), int(bbox[1]))
    p2 = (int(bbox[0] + bbox[2]), int(bbox[1] + bbox[3]))
    cv2.rectangle(frame, p1, p2, (255,0,0), 2, 1)

def displayRectangle(frame, bbox):
    plt.figure(figsize=(20,10))
    frameCopy = frame.copy()
    drawRectangle(frameCopy, bbox)
    frameCopy = cv2.cvtColor(frameCopy, cv2.COLOR_RGB2BGR)
    plt.imshow(frameCopy); plt.axis('off')    

def drawText(frame, txt, location, color = (50,170,50)):
    cv2.putText(frame, txt, location, cv2.FONT_HERSHEY_SIMPLEX, 0.75, color, 2)

# %% [markdown]
# # Goal
#
# ** Given the initial location of an object, track location in subsequent frames **
#
# ![Object Tracking](object-tracking.jpg)

# %%
# %%HTML
# <video width="1024" controls>
#   <source src="chaplin.mp4" type="video/mp4">
# </video>
# Out:
# <video width="1024" controls>
#   <source src="chaplin.mp4" type="video/mp4">
# </video>

# %% [markdown]
# # Tracker Class in OpenCV
#
# 1. BOOSTING
# 2. MIL
# 3. KCF
# 4. TLD
#  * Tends to recover from occulusions
# 5. MEDIANFLOW
#  * Good for predictable slow motion
# 6. GOTURN
#  * Deep Learning based
#  * Most Accurate
# 7. MOSSE
#  * Fastest

# %% [markdown]
# # Create the Tracker instance

# %%
# Set up tracker
tracker_types = ['BOOSTING', 'MIL','KCF', 'TLD', 'MEDIANFLOW', 'GOTURN','MOSSE']

# Change the index to change the tracker type
tracker_type = tracker_types[6]

if tracker_type == 'BOOSTING':
    tracker = cv2.TrackerBoosting_create()
elif tracker_type == 'MIL':
    tracker = cv2.TrackerMIL_create()
elif tracker_type == 'KCF':
    tracker = cv2.TrackerKCF_create()
elif tracker_type == 'TLD':
    tracker = cv2.TrackerTLD_create()
elif tracker_type == 'MEDIANFLOW':
    tracker = cv2.TrackerMedianFlow_create()
elif tracker_type == 'GOTURN':
    tracker = cv2.TrackerGOTURN_create()   
else:
    tracker = cv2.TrackerMOSSE_create()

# %% [markdown]
# # Read input video & Setup output Video

# %%
# Read video
video = cv2.VideoCapture("chaplin.mp4")
ok, frame = video.read()

# Exit if video not opened
if not video.isOpened():
    print("Could not open video")
    sys.exit()
else : 
    width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))

video_out = cv2.VideoWriter('chaplin-' + tracker_type + '.mp4',cv2.VideoWriter_fourcc(*'avc1'), 10, (width, height))

# %% [markdown]
# # Define Bounding Box

# %%
# Define a bounding box
bbox = (276, 23, 86, 320)
#bbox = cv2.selectROI(frame, False)

displayRectangle(frame,bbox)

# %% [markdown]
# # Intilialize Tracker
#
# 1. One frame
# 2. A bounding box
# 3. Tracking model (for GOTURN only)

# %%
# Initialize tracker with first frame and bounding box
if tracker_type=="GOTURN":
    if not os.path.isfile('goturn.prototxt'):
        print("Downloading GOTURN prototxt")
        # !wget -q --show-progress https://www.dropbox.com/s/ta50nrqz8y2lf9n/goturn.prototxt?dl=0 -O goturn.prototxt
    if not os.path.isfile('goturn.caffemodel'):
        print("Downloading GOTURN Cafee Model")
        # !wget -q --show-progress https://www.dropbox.com/s/wq6ws27eduj56ql/goturn.caffemodel?dl=0 -O goturn.caffemodel

ok = tracker.init(frame, bbox)

# %% [markdown]
# # Read frame and Track Object

# %%
while True:
    ok, frame = video.read()
    if not ok:
        break 
    
    # Start timer
    timer = cv2.getTickCount()

    # Update tracker
    ok, bbox = tracker.update(frame)

    # Calculate Frames per second (FPS)
    fps = cv2.getTickFrequency() / (cv2.getTickCount() - timer);

    # Draw bounding box
    if ok:
        drawRectangle(frame, bbox)
    else :
        drawText(frame, "Tracking failure detected", (100,80), (0, 0, 255))

    # Display Info
    drawText(frame, tracker_type + " Tracker", (100,20))
    drawText(frame, "FPS : " + str(int(fps)), (100,50))
    
    # Write frame to video
    video_out.write(frame)
    
video.release()
video_out.release()

# %%
# %%HTML
# <video width="1024" controls>
#   <source src="chaplin-out.mp4" type="video/mp4">
# </video>
# Out:
# <video width="1024" controls>
#   <source src="chaplin-out.mp4" type="video/mp4">
# </video>

# %% [markdown]
# # Thank You!
